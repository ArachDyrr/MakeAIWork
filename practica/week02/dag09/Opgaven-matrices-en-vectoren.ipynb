# %% [markdown]
# # Matrices en vectoren

# %% [markdown]
# Er zijn meerdere manieren om een matrix te representeren.
#
# Hier kiezen we voor het volgende datamodel:
#
# `matrix_2D :: {rows: int, cols: int, data: []}`
#
# Implementeer onderstaande opdrachten in Python.

# %% [markdown]
# ## Vectoren

# %% [markdown]
# ### 1. Een vector als rij*

# %% [markdown]
# Representeer de onderstaande vector in code:
#
# $$
#   \begin{pmatrix}
#     1 & 2 & 3
#   \end{pmatrix}
# $$

# %%
# How many rows and colums does this vector have?

# ...1

# Use the definition at the top to implement this vector:

vecR = {'rows': 1, 'cols': 3, 'data': [1,2,3]}
# vec = {1,3,[1,2,3]}

# Can you print its dimensions? (rows, cols)

print(f"The number of rows is:_____{vecR['rows']} \nThe number of columns is:__{vecR['cols']}")


# Can you print the number of elements?

print(f"The length of the nr of elements is:_{len(vecR['data'])} ")


# ...
# Out:
# The number of rows is:_____1
# The number of columns is:__3
# The length of the nr of elements is:_3

# %%
type(vecR)
# Out:
# dict

# %% [markdown]
# ### 2. Een vector als kolom*

# %% [markdown]
# Representeer de onderstaande vector in code:
#
# $$
#   \begin{pmatrix}
#     1 \\
#     2 \\
#     3
#   \end{pmatrix}
# $$

# %%
# How many rows and colums does this vector have?

# ... 3 rows and 1 column

# Use the definition at the top to implement this vector:

vecC = {'rows': 3, 'cols': 1, 'data': [1,2,3]}

# Can you print its dimensions? (rows, cols)

print(f"The number of rows is:_____{vecC['rows']} \nThe number of columns is:__{vecC['cols']}")

# Can you print the number of elements?

print(f"The length of the nr of elements is:_{len(vecC['data'])} ")
# Out:
# The number of rows is:_____3
# The number of columns is:__1
# The length of the nr of elements is:_3

# %% [markdown]
# ### 3. Vectoren optellen**

# %% [markdown]
# Tel de onderstaande vectoren bij elkaar op:
#
# $$
#   \begin{pmatrix}
#     1 \\
#     2 \\
#     3
#   \end{pmatrix}
#   +
#     \begin{pmatrix}
#     9 \\
#     8 \\
#     7
#   \end{pmatrix}
#   =
#   ...
# $$

# %%
# Implement both vectors:

vec1 = {'rows': 3, 'cols': 1, 'data': [1,2,3]}
vec2 = {'rows': 3, 'cols': 1, 'data': [9,8,7]}

# Can we add them? Check if dimensions are the same:

addable=vec1['rows']==vec2['rows'] and vec1['cols']==vec2['cols']

if addable:
    print ('We can add these vectors because the following is true: the amount of rows is equal and the amount of columns is equal.')
else:
    print('werkt niet')

# How do you add these vectors by hand?

print("(1) (9) (1+9) (10)\n(2)+(8)=(2+8)=(10)\n(3) (7) (3+7) (10)")

# Now add the vectors in code:


if not addable:
    print('these fectors are not addable')
else:
    vec3 = {'rows': 0, 'cols': 0, 'data': [0,0,0]}
    vec3['rows']=vec1['rows']
    vec3['cols']=vec2['cols']
    vec3['data'][0] =vec1['data'][0]+vec2['data'][0]
    vec3['data'][1] =vec1['data'][1]+vec2['data'][1]
    vec3['data'][2] =vec1['data'][2]+vec2['data'][2]
    print (vec3)


# ...
# Out:
# We can add these vectors because the following is true: the amount of rows is equal and the amount of columns is equal.
# (1) (9) (1+9) (10)
# (2)+(8)=(2+8)=(10)
# (3) (7) (3+7) (10)
# {'rows': 3, 'cols': 1, 'data': [10, 10, 10]}

# %% [markdown]
# Tel de onderstaande vectoren bij elkaar op:
#
# $$
#   \begin{pmatrix}
#     1 & 2 & 3
#   \end{pmatrix}
#   +
#   \begin{pmatrix}
#     9 & 8 & 7
#   \end{pmatrix}
#   =
#   ...
# $$

# %%
# Implement both vectors:

vec1 = {'rows': 1, 'cols': 3, 'data': [1,2,3]}
vec2 = {'rows': 1, 'cols': 3, 'data': [9,8,7]}

# Can we add them? Check if dimensions are the same:

addable=vec1['rows']==vec2['rows'] and vec1['cols']==vec2['cols'] and len(vec1['data'])==len(vec2['data']) and vec1['rows']*vec1['cols']==len(vec1['data'])

if addable == True:
    print ('We can add these vectors because the following is true: the amount of rows is equal and the amount of columns is equal. \nAnd The amount of elements in the data is equal to rows times columns ')

# How do you add these vectors by hand?

print("(1 2 3)+(9 8 7)=(1+9 2+8 3+7)=(10 10 10)")

# Now add the vectors in code:

if addable != True:
    print('these vectors are not addable')
else:
    vec3 = {'rows': 0, 'cols': 0, 'data': [0,0,0]}
    vec3['rows']=vec1['rows']
    vec3['cols']=vec2['cols']
    vec3['data'][0] =vec1['data'][0]+vec2['data'][0]
    vec3['data'][1] =vec1['data'][1]+vec2['data'][1]
    vec3['data'][2] =vec1['data'][2]+vec2['data'][2]
    print (vec3)
# ...
# Out:
# We can add these vectors because the following is true: the amount of rows is equal and the amount of columns is equal.
# And The amount of elements in the data is equal to rows tiems columns
# (1 2 3)+(9 8 7)=(1+9 2+8 3+7)=(10 10 10)
# {'rows': 1, 'cols': 3, 'data': [10, 10, 10]}

# %% [markdown]
# ## Matrices

# %% [markdown]
# ### 1. Een 3 x 3 matrix*

# %% [markdown]
# Representeer de onderstaande matrix in code:
#
# $$
#   \begin{pmatrix}
#     1 & 2 & 3\\
#     4 & 5 & 6\\
#     7 & 8 & 9\\
#   \end{pmatrix}
# $$

# %%
# How many rows and colums does this matrix have?

# ...the amount of rows i 3 as is the amount of columns

# Use the definition at the top to implement this matrix:

mat = {'rows': 3, 'cols': 3, 'data': [1,2,3,4,5,6,7,8,9]}

# Can you print its dimensions? (rows, cols)

print(f"The number of rows is:_____{mat['rows']} \nThe number of columns is:__{mat['cols']}")


# Can you print the number of elements?

print(f"The length of the nr of elements is:_the lists in data = {len(mat['data'])} ")
# Out:
# The number of rows is:_____3
# The number of columns is:__3
# The length of the nr of elements is:_the lists in data = 9

# %% [markdown]
# ### 2. Matrices optellen**

# %% [markdown]
# Tel de onderstaande matrices op:
#
# $$
#   \begin{pmatrix}
#     1 & 2 & 3\\
#     4 & 5 & 6\\
#     7 & 8 & 9\\
#   \end{pmatrix}
#   +
#     \begin{pmatrix}
#     9 & 8 & 7\\
#     6 & 5 & 4\\
#     3 & 2 & 1\\
#   \end{pmatrix}
#   =
#   ...
# $$

# %%
# Implement both matrices:

mat1 = {'rows': 3, 'cols': 3, 'data': [1,2,3,4,5,6,7,8,9]}
mat2 = {'rows': 3, 'cols': 3, 'data': [9,8,7,6,5,4,3,2,1]}

# Can we add them? Check if dimensions are the same:

addable_mat=mat1['rows']==mat2['rows'] and mat1['cols']==mat2['cols']and len(mat1['data'])==len(mat2['data']) and mat1['rows']*mat1['cols']==len(mat1['data'])
if addable_mat == True:
    print ('We can add these matrixes because the following is true: the amount of rows is equal and the amount of columns is equal. \nAnd The amount of elements in the data is equal to rows times columns ')

# How do you add these matrices by hand?
# calculate position one of the result by adding the sum of position 1 of mat1 to position 1 of mat2
# calculate position one of the result by adding the sum of position 2 of mat1 to position 2 of mat2
# continue till all 9 positions are filled


# Now add the matrices in code:

### MET FOR IN RANGE METHODE
if addable_mat!= True:
    print ("Matrixes are not addable!")
else:
    mat3={'rows': 0, 'cols': 0, 'data': [0,0,0,0,0,0,0,0,0]}
    mat3['rows']=mat1['rows']
    mat3['cols']=mat2['cols']
    for n in range (len(mat3['data'])):
        mat3['data'][n] = (mat1['data'][n]+mat2['data'][n])
    print (mat3)

### MET ELSE METHODE
# if addable_mat!= True:
#     print ("Matrixes are not addable!")
# else:
#     n=0
#     mat3={'rows': 0, 'cols': 0, 'data': [0,0,0,0,0,0,0,0,0]}
#     mat3['rows']=mat1['rows']
#     mat3['cols']=mat2['cols']
#     while n < len(mat3['data']):
#         mat3['data'][n] = (mat1['data'][n]+mat2['data'][n])
#         n += 1
#     print (mat3)

 

## In case you didn't: can you generalize this algorithm?

# I could make it more general by creating the data string with the length of the addable strings. one easy way would be  along the # lines of mat3=mat1.copy()
# Out:
# We can add these matrixes because the following is true: the amount of rows is equal and the amount of columns is equal.
# And The amount of elements in the data is equal to rows times columns
# {'rows': 3, 'cols': 3, 'data': [10, 10, 10, 10, 10, 10, 10, 10, 10]}

# %%
mat4 = {'rows': 3, 'cols': 3, 'data': [1,2,3,4,5,6,7,8,9]}
mat5 = mat4.copy()
print (mat5)
# Out:
# {'rows': 3, 'cols': 3, 'data': [1, 2, 3, 4, 5, 6, 7, 8, 9]}

# %% [markdown]
# ### 3. Matrices vermenigvuldigen***

# %% [markdown]
# Vermenigvuldig de onderstaande matrices:
#
# $$
#   \begin{pmatrix}
#     1 & 2 & 3\\
#     4 & 5 & 6
#   \end{pmatrix}
#   *
#     \begin{pmatrix}
#     9 & 8\\
#     6 & 5\\
#     3 & 2\\
#   \end{pmatrix}
#   =
#   ...
# $$

# %%
# Implement both matrices:

mat1 = {'rows': 2, 'cols': 3, 'data': [1,2,3,4,5,6]}
mat2 = {'rows': 3, 'cols': 2, 'data': [9,8,6,5,3,2]}

# Can we multiply them? Check if dimensions satisfy the (M by N) * (N by K) = (M by K) rule:

# The (M by N) * (N by K) = (M by K) rule determines the final dimantions of the result of the matrix. 
# For a muliplication to be possible, the columns of the first matrix (N) need to be equal to the number of rows on the 2nd matrix (N)

multipliable=mat1['cols']==mat2['rows']
if multipliable == True:
    print ('These matrixes are multipliable!')
# ...

# How do you multiply these matrices by hand?
#|(mat1[0] *mat2[0]) + (mat1[1]*mat2[2]) + (mat1[2]*mat2[4]) | (mat1[1] *mat2[1]) + (mat1[2]*mat2[3]) + (mat1[3]*mat2[5])
#|(mat1[3] *mat2[0]) + (mat1[4]*mat2[2]) + (mat1[5]*mat2[4]) | (mat1[3] *mat2[1]) + (mat1[4]*mat2[3]) + (mat1[5]*mat2[5])

## m1[0]*m2[0]+m1[0+1]*m2[0+2]+m1[0+1+1]*m2[0+2+2]|m1[0]*m2[1]+m1[0+1]*m2[1+2]+m1[0+1+1]*m2[1+2+2] =
## m1[3]*m2[0]+m1[3+1]*m2[0+2]+m1[3+1+1]*m2[0+2+2]|m1[3]*m2[1]+m1[3+1]*m2[1+2]+m1[3+1+1]*m2[1+2+2] = 

# Now multiply the matrices in code:

mat3 = {'rows': mat2['cols'], 'cols': mat1['rows'], 'data': [0]*mat1['rows']*mat2['cols']}
# n=0
# a=0
# A=mat1['data']
# B=mat2['data']
# mat3['data'][0]=A[0]

mat1 = {'rows': 2, 'cols': 3, 'data': [1, 2, 3, 4, 5, 6]}
mat2 = {'rows': 3, 'cols': 2, 'data': [9, 8, 6, 5, 3, 2]}

mat3 = {'rows': mat2['cols'], 'cols': mat1['rows'], 'data': [0]*mat1['rows']*mat2['cols']}

# def calulator(n,y,z,e):
#     while n < 3:
#     e = m1[z]*m2[y]
#     n += 1
#     z += 1
#     y +=2
#     e0 += e



m1 = mat1['data']
m2 = mat2['data']

e0 = 0
e1 = 0
e2 = 0
e3 = 0


n=0
y=0
z=n
e=0
while n < 3:
    e = m1[z]*m2[y]
    n += 1
    z += 1
    y +=2
    e0 += e

    
n=0
y=1
z=0
e=0
while n < 3:
    e = m1[z]*m2[y]
    n += 1
    z +=1
    y +=2
    e1 += e
   
    
n=0
y=0
z=n+3
e=0

while  n < 3:
    e = m1[z]*m2[y]
    n += 1
    z += 1
    y += 2
    e2 += e
    
 
    
n=0
y=1
z=n+3
e=0

while  n < 3:
    e = m1[z]*m2[y]
    n += 1
    z += 1
    y += 2
    e3 += e
    
   

    


mat3['data'][0]=e0
mat3['data'][1]=e1
mat3['data'][2]=e2
mat3['data'][3]=e3


print (mat3)

# In case you didn't: can you generalize this algorithm?

# ...
# Out:
# These matrixes are multipliable!
# {'rows': 2, 'cols': 2, 'data': [30, 24, 84, 69]}

# %%
def calulator(el):
    while n < 3:
        e = m1[z]*m2[y]
        n += 1
        z += 1
        y +=2
        el += e
        return el

mat1 = {'rows': 2, 'cols': 3, 'data': [1, 2, 3, 4, 5, 6]}
mat2 = {'rows': 3, 'cols': 2, 'data': [9, 8, 6, 5, 3, 2]}

mat3 = {'rows': mat2['cols'], 'cols': mat1['rows'], 'data': [0]*mat1['rows']*mat2['cols']}
el=0

n=0
y=0
z=n
e=0

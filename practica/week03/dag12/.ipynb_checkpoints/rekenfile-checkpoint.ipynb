# %%
import math

# %%
x1=abs(6-2)**2
x2=abs(3-3)**2
x3=abs(4-5)**2
x4=abs(5-4)**2

# %%
a1_a2=math.sqrt(x1+x2+x3+x4)
print (a1_a2)
# Out:
# 4.242640687119285

# %%
x1=abs(6-9)**2
x2=abs(3-1)**2
x3=abs(4-1)**2
x4=abs(5-8)**2
a1_a4=math.sqrt(x1+x2+x3+x4)
print (a1_a4)
# Out:
# 5.5677643628300215

# %%
x1=abs(6-8)**2
x2=abs(3-2)**2
x3=abs(4-0)**2
x4=abs(5-9)**2
a1_a5=math.sqrt(x1+x2+x3+x4)
print (a1_a5)
# Out:
# 6.082762530298219

# %%
x1=abs(6-8)**2
x2=abs(3-0)**2
x3=abs(4-1)**2
x4=abs(5-8)**2
a1_a6=math.sqrt(x1+x2+x3+x4)
print (a1_a6)
# Out:
# 5.5677643628300215

# %%
x1=abs(2-9)**2
x2=abs(3-1)**2
x3=abs(5-1)**2
x4=abs(4-8)**2
a2_a4=math.sqrt(x1+x2+x3+x4)
print (a2_a4)
# Out:
# 9.219544457292887

# %%
x1=abs(2-8)**2
x2=abs(3-2)**2
x3=abs(5-0)**2
x4=abs(4-9)**2
a2_a5=math.sqrt(x1+x2+x3+x4)
print (a2_a5)
# Out:
# 9.327379053088816

# %%
x1=abs(2-8)**2
x2=abs(3-0)**2
x3=abs(5-1)**2
x4=abs(4-8)**2
a2_a6=math.sqrt(x1+x2+x3+x4)
print (a2_a6)
# Out:
# 8.774964387392123

# %%
x1=abs(5-9)**2
x2=abs(4-1)**2
x3=abs(6-1)**2
x4=abs(3-8)**2
a3_a4=math.sqrt(x1+x2+x3+x4)
print (a3_a4)
# Out:
# 8.660254037844387

# %%
x1=abs(5-8)**2
x2=abs(4-2)**2
x3=abs(6-0)**2
x4=abs(3-9)**2
a3_a5=math.sqrt(x1+x2+x3+x4)
print (a3_a5)
# Out:
# 9.219544457292887

# %%
x1=abs(5-8)**2
x2=abs(4-0)**2
x3=abs(6-1)**2
x4=abs(3-8)**2
a3_a6=math.sqrt(x1+x2+x3+x4)
print (a3_a6)
# Out:
# 8.660254037844387

# %%
c1 = {(6+2+5)/3,(3+3+4)/4,(5+5+6)/3,(5+4+3)/3}
c2 = {(+9+8+8)/3,(1+2+0)/3,(1+0+1)/3,(8+9+8)/3}
print (f'het centrum canb kluster 1 is: {c1}')
print (f'het centrum canb kluster 1 is: {c2}')
# Out:
# het centrum canb kluster 1 is: {2.5, 4.0, 4.333333333333333, 5.333333333333333}
# het centrum canb kluster 1 is: {8.333333333333334, 1.0, 0.6666666666666666}

# %%
# de afstand tussen het centrum van cluster 1 en cluster 2

x1=abs((6+2+5)/3-(+9+8+8)/3)**2
x2=abs((3+3+4)/4-(1+2+0)/3)**2
x3=abs((5+5+6)/3-(1+0+1)/3)**2
x4=abs((5+4+3)/3-(8+9+8)/3)**2
c1_c2=math.sqrt(x1+x2+x3+x4)
print (f' De afstand tussen de centra van de clusters is: {c1_c2}')
# Out:
#  De afstand tussen de centra van de clusters is: 7.668478046884894

# %% [markdown]
# <a href="https://it-omscholing.nl/locaties/hogeschool-rotterdam/">
# <div>
# <a><img src='raw_downloads/pics/banner.PNG'/></a>
# </div>
# <div>
# <a href=''><img src='raw_downloads/pics/miw.PNG'/></a>
# <em>Author: Stephan Dekker</em>
# </div>
# </a>

# %%
# ** Voorbereidingen dag 1**
# Out:
#   Cell In[7], line 1
#     ** Voorbereidingen dag 1**
#     ^
# SyntaxError: invalid syntax

# %%
# ... Haal de ruwe data te vinden in de fictieve API fictieve site van het Medisch Centrum Randstad  https://mc-randstad.netlify.app/data.csv met de Thunder Client in VS code.

# ... Maak een nieuwe file. noem deze data_raw.csv In deze file sla je de geimporterde data op.

# %%
# ... Haal de ruwe data te vinden in de fictieve API fictieve site van het Medisch Centrum Randstad  http://localhost:8080/medish_centrum_randstad/api/netlify?page=1 met de Thunder Client in VS code.

# ... Maak een nieuwe file. noem deze data_raw.json In deze file sla je de geimporterde data op.
